# %%
from pipelines.oulad_pypeline import bulk_copy_runner

# if __name__ == "__main__":
#     bulk_copy_runner()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import j
#       2
#       3 # if __name__ == "__main__":
#       4 #     bulk_copy_runner()
#
# File d:\Documents\Ciencias de datos\Ciencias de datos 1\unidad 3\caso_practico_2_oulad\src\notebooks\j.py:1
# ----> 1 from pipelines.oulad_pypeline import bulk_copy_runner
#       3 def pipeline_runner():
#       4     bulk_copy_runner()
#
# ModuleNotFoundError: No module named 'pipelines'
